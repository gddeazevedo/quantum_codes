# %%
from qiskit import QuantumCircuit
from qiskit.quantum_info import Operator, Statevector

# %%
n_qubits = 1
n_cbits  = 1

qubit = 0 # the index of the qubit in the circuit
cbit  = 0 # the index of the classical bit

qc = QuantumCircuit(n_qubits, n_cbits)

qc.reset(0)
qc.x(0)
qc.measure(qubit, cbit) # measure qubit index 0 and store the result in the classical bit index 0

qc.draw()
# Out:
#           ┌───┐┌─┐
#   q: ─|0>─┤ X ├┤M├
#           └───┘└╥┘
# c: 1/═══════════╩═
#                 0

# %%
qc_x = QuantumCircuit(1)
qc_x.x(0)
X = Operator(qc_x)
X.draw('latex')
# Out:
# $$
#
# \begin{bmatrix}
# 0 & 1  \\
#  1 & 0  \\
#  \end{bmatrix}
# $$

# %%
X = Operator.from_label('X')
ket_0 = Statevector.from_label('0')
ket_0.evolve(X).draw('latex')
# Out:
# $$ |1\rangle$$

# %%
ket_1 = Statevector.from_label('1')
ket_1.evolve(X).draw('latex')
# Out:
# $$ |0\rangle$$

# %%
H = Operator.from_label('H')
ket_0.evolve(H).draw('latex')
# Out:
# $$\frac{\sqrt{2}}{2} |0\rangle+\frac{\sqrt{2}}{2} |1\rangle$$

# %%
ket_1.evolve(H).draw('latex')
# Out:
# $$\frac{\sqrt{2}}{2} |0\rangle- \frac{\sqrt{2}}{2} |1\rangle$$

# %%
H.draw('latex')
# Out:
# $$
#
# \begin{bmatrix}
# \frac{\sqrt{2}}{2} & \frac{\sqrt{2}}{2}  \\
#  \frac{\sqrt{2}}{2} & - \frac{\sqrt{2}}{2}  \\
#  \end{bmatrix}
# $$

# %%
from qiskit.providers.basic_provider import BasicSimulator


sim = BasicSimulator()
n_qubits = 1
n_cbits  = 1

qubit = 0 # the index of the qubit in the circuit
cbit  = 0 # the index of the classical bit

qc = QuantumCircuit(n_qubits, n_cbits)

qc.h(0)
qc.measure(qubit, cbit) # measure qubit index 0 and store the result in the classical bit index 0

qc.draw()
# Out:
#      ┌───┐┌─┐
#   q: ┤ H ├┤M├
#      └───┘└╥┘
# c: 1/══════╩═
#            0

# %%
job = sim.run(qc, shots=100)
result = job.result()
counts = result.get_counts()
print(counts)
# Out:
# {'0': 54, '1': 46}

# %% [markdown]
# # Bell State

# %%
qc = QuantumCircuit(2, 2)
qc.reset(0)
qc.reset(1)
qc.h(0)
qc.cx(0, 1)

qc.measure(0, 0)
qc.measure(1, 1)
qc.draw()
# Out:
#           ┌───┐     ┌─┐
# q_0: ─|0>─┤ H ├──■──┤M├───
#           └───┘┌─┴─┐└╥┘┌─┐
# q_1: ─|0>──────┤ X ├─╫─┤M├
#                └───┘ ║ └╥┘
# c: 2/════════════════╩══╩═
#                      0  1

# %%
sim = BasicSimulator()
job = sim.run(qc, shots=100)
result = job.result()

counts = result.get_counts()

print(counts)
# Out:
# {'11': 49, '00': 51}
